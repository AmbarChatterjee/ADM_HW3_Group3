# %% [markdown]
# ## QUESTION 4

# %% [markdown]
# In this exercise, we aim to represent various courses on a geographic map.
# Additionally, we want the color of each course to depend on the price.

# %% [markdown]
# At first, let's import the dataset and take a look to the variables we are interested in.

# %%
import pandas as pd

courses = pd.read_csv("courses_data_processed.tsv", sep='\t')

print(courses[["courseName", "city", "country"]])
# Out:
#                                              courseName     city  \
# 0              3D Design for Virtual Environments - MSc  Glasgow
# 1                          Accounting and Finance - MSc    Leeds
# 2     Accounting, Accountability & Financial Managem...   London
# 3     Accounting, Financial Management and Digital B...  Reading
# 4                                        Addictions MSc   London
# ...                                                 ...      ...
# 5995                              Materials Engineering    Padua
# 5996                          Materials Engineering MSc  Swansea
# 5997              Materials Engineering MSc by Research  Swansea
# 5998           Materials Engineering with Industry, MSc  Swansea
# 5999           Materials for Energy and Environment MSc   London
#
#              country
# 0     United Kingdom
# 1     United Kingdom
# 2     United Kingdom
# 3     United Kingdom
# 4     United Kingdom
# ...              ...
# 5995           Italy
# 5996  United Kingdom
# 5997  United Kingdom
# 5998  United Kingdom
# 5999  United Kingdom
#
# [6000 rows x 3 columns]

# %% [markdown]
# Now we import some of the packages we will need.

# %%
# !pip install keplergl
# !pip install googlemaps
# !pip install gmaps
# !pip install geopandas

import pandas as pd
from googlemaps import Client as GoogleMaps
import googlemaps
import gmaps
from keplergl import KeplerGl
import geopandas as gpd
# Out:
# Requirement already satisfied: keplergl in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: ipywidgets<8,>=7.0.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from keplergl) (7.8.1)
# Requirement already satisfied: traittypes>=0.2.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from keplergl) (0.2.1)
# Requirement already satisfied: geopandas>=0.5.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from keplergl) (0.14.1)
# Requirement already satisfied: pandas>=0.23.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from keplergl) (1.5.3)
# Requirement already satisfied: Shapely>=1.6.4.post2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from keplergl) (2.0.2)
# Requirement already satisfied: fiona>=1.8.21 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas>=0.5.0->keplergl) (1.9.5)
# Requirement already satisfied: packaging in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas>=0.5.0->keplergl) (23.0)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas>=0.5.0->keplergl) (3.6.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (8.12.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (1.1.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pandas>=0.23.0->keplergl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pandas>=0.23.0->keplergl) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pandas>=0.23.0->keplergl) (1.24.3)
# Requirement already satisfied: attrs>=19.2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.5.0->keplergl) (22.1.0)
# Requirement already satisfied: certifi in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.5.0->keplergl) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.5.0->keplergl) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.5.0->keplergl) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.5.0->keplergl) (0.7.2)
# Requirement already satisfied: six in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.5.0->keplergl) (1.16.0)
# Requirement already satisfied: setuptools in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas>=0.5.0->keplergl) (68.0.0)
# Requirement already satisfied: backcall in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: decorator in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.15.1)
# Requirement already satisfied: stack-data in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (4.8.0)
# Requirement already satisfied: appnope in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.3)
# Requirement already satisfied: jinja2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (23.2.0)
# Requirement already satisfied: argon2-cffi in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (7.4.9)
# Requirement already satisfied: nbformat in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.5.6)
# Requirement already satisfied: ipykernel in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.5.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.5)
# Requirement already satisfied: executing in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.3)
# Requirement already satisfied: asttokens in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.2)
# Requirement already satisfied: entrypoints in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (2.5.2)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.2.2)
# Requirement already satisfied: lxml in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (4.12.2)
# Requirement already satisfied: bleach in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.2.1)
# Requirement already satisfied: fastjsonschema in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.6.7)
# Requirement already satisfied: psutil in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (5.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (3.5.0)
# Requirement already satisfied: websocket-client in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (2.4)
# Requirement already satisfied: webencodings in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (1.2.0)
# Requirement already satisfied: pycparser in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7.0.0->keplergl) (2.21)
# Requirement already satisfied: googlemaps in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.7.22)
# Requirement already satisfied: gmaps in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from gmaps) (8.12.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from gmaps) (7.8.1)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from gmaps) (5.7.1)
# Requirement already satisfied: geojson>=2.0.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from gmaps) (3.1.0)
# Requirement already satisfied: six in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: backcall in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: decorator in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (2.15.1)
# Requirement already satisfied: stack-data in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: appnope in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->gmaps) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->gmaps) (1.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (6.5.4)
# Requirement already satisfied: executing in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: asttokens in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->gmaps) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.2.2)
# Requirement already satisfied: jinja2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (23.2.0)
# Requirement already satisfied: argon2-cffi in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (7.4.9)
# Requirement already satisfied: nbformat in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.5.6)
# Requirement already satisfied: ipykernel in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.5.5)
# Requirement already satisfied: entrypoints in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (2.5.2)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.2.2)
# Requirement already satisfied: lxml in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (4.12.2)
# Requirement already satisfied: bleach in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: packaging in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (23.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.2.1)
# Requirement already satisfied: fastjsonschema in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.6.7)
# Requirement already satisfied: psutil in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (3.5.0)
# Requirement already satisfied: websocket-client in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (2.4)
# Requirement already satisfied: webencodings in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (1.2.0)
# Requirement already satisfied: pycparser in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: geopandas in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (0.14.1)
# Requirement already satisfied: fiona>=1.8.21 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.4.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (1.24.3)

# %% [markdown]
# We need 'city' and 'country' to define a new variable, 'Full_Address,' which we will use to import coordinates from Google Maps.

# %%
courses['Full_Address'] = courses['city'] + ',' + courses['country']
print(courses['Full_Address'])
# Out:
# 0       Glasgow,United Kingdom
# 1         Leeds,United Kingdom
# 2        London,United Kingdom
# 3       Reading,United Kingdom
# 4        London,United Kingdom
#                  ...
# 5995               Padua,Italy
# 5996    Swansea,United Kingdom
# 5997    Swansea,United Kingdom
# 5998    Swansea,United Kingdom
# 5999     London,United Kingdom
# Name: Full_Address, Length: 6000, dtype: object

# %% [markdown]
# Now let's insert the API key obtained by signing up for Google Developer Console, to obtain latitude and longitude coordinates from 'Full_Address'.

# %%
gmaps = googlemaps.Client(key='AIzaSyBArdb62x51edUdvhgJszeJ_LXFU8jibfY')

# %% [markdown]
# Let's just pass the 'Full_address' column to the google API.

# %%
courses1= courses.iloc[:,-1:].copy()
courses1.head()
# Out:
#              Full_Address
# 0  Glasgow,United Kingdom
# 1    Leeds,United Kingdom
# 2   London,United Kingdom
# 3  Reading,United Kingdom
# 4   London,United Kingdom

# %% [markdown]
# Now we create two empty columns that will be filled with the latitude and longitude coordinates.

# %%
courses1['long'] = ""
courses1['lat'] = ""

# %% [markdown]
# Using the Google Maps Geocoding API to retrieve latitude and longitude coordinates for addresses stored in the 'Full_Address' column of the 'courses1' DataFrame.

# %%
for x in range(len(courses1)): #iterate over the rows of the 'courses1'
    geocode_result = gmaps.geocode(courses1['Full_Address'][x]) #send a geocoding request to the Google Maps Geocoding API for the address in the 'Full_Address' column of the current row
    if geocode_result: #check if the geocoding request was successful
        #latitude and longitude coordinates are extracted from the API response and assigned to the 'lat' and 'long' columns of the 'courses1'
        courses1['lat'][x] = geocode_result[0]['geometry']['location']['lat']
        courses1['long'][x] = geocode_result[0]['geometry']['location']['lng']
    else:
        #if we don't have any result it sets the 'lat' and 'long' columns for the current row to empty strings
        courses1['lat'][x] = "" 
        courses1['long'][x] = ""

# %% [markdown]
# Insert the new variables in the original dataset.

# %%
courses['Lat']=courses1['lat']
courses['Lon']= courses1['long']
courses.head()
# Out:
#                                           courseName  \
# 0           3D Design for Virtual Environments - MSc
# 1                       Accounting and Finance - MSc
# 2  Accounting, Accountability & Financial Managem...
# 3  Accounting, Financial Management and Digital B...
# 4                                     Addictions MSc
#
#                   universityName  \
# 0  Glasgow Caledonian University
# 1            University of Leeds
# 2          King’s College London
# 3          University of Reading
# 4          King’s College London
#
#                                          facultyName         isItFullTime  \
# 0        School of Engineering and Built Environment            Full time
# 1                   Leeds University Business School            Full time
# 2                             King’s Business School            Full time
# 3                             Henley Business School            Full time
# 4  Institute of Psychiatry, Psychology and Neuros...  Full time&Part time
#
#                                          description  startDate     fees  \
# 0  3D visualisation and animation play a role in ...  September      NaN
# 1  Businesses and governments rely on sound finan...  September  34750.0
# 2  Our Accounting, Accountability & Financial Man...  September      NaN
# 3  Embark on a professional accounting career wit...  September      NaN
# 4  Join us for an online session for prospective ...  September      NaN
#
#   modality          duration     city         country administration  \
# 0      MSc  1 year full-time  Glasgow  United Kingdom      On Campus
# 1      MSc  1 year full time    Leeds  United Kingdom      On Campus
# 2      MSc         1 year FT   London  United Kingdom      On Campus
# 3      MSc  1 year full time  Reading  United Kingdom      On Campus
# 4      MSc       One year FT   London  United Kingdom      On Campus
#
#                                                  url  \
# 0  https://www.findamasters.com/masters-degrees/c...
# 1  https://www.findamasters.com/masters-degrees/c...
# 2  https://www.findamasters.com/masters-degrees/c...
# 3  https://www.findamasters.com/masters-degrees/c...
# 4  https://www.findamasters.com/masters-degrees/c...
#
#                                 ProcessedDescription currency  fees (EUR)  \
# 0  3d visualis anim play role mani area popular m...      NaN         NaN
# 1  busi govern reli sound financi knowledg underp...        £    39869.21
# 2  account account  financi manag msc cours provi...      NaN         NaN
# 3     embark profession account career academ ground      NaN         NaN
# 4  join us onlin session prospect student find ms...      NaN         NaN
#
#              Full_Address        Lat       Lon
# 0  Glasgow,United Kingdom   55.86167 -4.258335
# 1    Leeds,United Kingdom  53.800755 -1.549077
# 2   London,United Kingdom  51.507218 -0.127586
# 3  Reading,United Kingdom   51.45512 -0.978747
# 4   London,United Kingdom  51.507218 -0.127586

# %% [markdown]
# At this point, we have the coordinates for the city and country of each course.
# Now, we want to be able to visualize information about the cost of the courses on the map.

# %%
#Drop the null values
courses = courses.dropna(subset=["fees (EUR)"]) 
print(courses["fees (EUR)"])
# Out:
# 1       39869.21
# 5       35566.77
# 7       15000.00
# 8       15000.00
# 9       32985.31
#           ...
# 5982     3203.07
# 5983    29900.00
# 5984    29900.00
# 5992    16177.15
# 5999    16177.15
# Name: fees (EUR), Length: 1228, dtype: float64

# %% [markdown]
# Now we have 1228 courses.

# %% [markdown]
# Let's divide the variable into price ranges.

# %%
#See what's the maximum price
print(max(courses['fees (EUR)']))
# Out:
# 114160191.6

# %%
#Define the ranges and create a new variable 
intervals=[0, 1000, 10000, 100000, 1000000, max(courses['fees (EUR)'])]
labels = ['<1k', '1k-10k', '10k-100k', '100k-1M', '>1M']
courses['fees_interval'] = pd.cut(courses['fees (EUR)'], bins=intervals, labels=labels)

#Let's see how many courses we have for each range
print(courses['fees_interval'].value_counts())
# Out:
# 10k-100k    936
# 1k-10k      148
# <1k         118
# 100k-1M       9
# >1M           3
# Name: fees_interval, dtype: int64

# %% [markdown]
# Let's see our first option for the map. It is interactive so you must run the code to see it.

# %%
# !pip install folium
# !pip install folium --upgrade

import folium
from folium.plugins import MarkerCluster

# Create a map centered on an initial location.
m = folium.Map(location=[courses['Lat'].mean(), courses['Lon'].mean()], zoom_start=10)

# Create a marker cluster.
marker_cluster = MarkerCluster().add_to(m)

# Define colors and default color.
colors = {'<1k': 'blue', '1k-10k': 'green', '10k-100k': 'orange', '100k-1M': 'red', '>1M': 'purple'}
default_color = 'gray'  # Default color for values NaN

# Iterate through the DataFrame and add markers to the cluster
for index, row in courses.iterrows():
    fee_interval = row['fees_interval'] if not pd.isna(row['fees_interval']) else None
    color = colors.get(fee_interval, default_color)

    # Add the marker to the cluster with the appropriate color, and the course name as a label.
    folium.Marker([row['Lat'], row['Lon']], popup=row['Full_Address'], icon=folium.Icon(color=color), tooltip=row['courseName']).add_to(marker_cluster)

# Add legend
legend_html = '''
     <div style="position: fixed; 
                 bottom: 50px; left: 50px; width: 150px; height: 180px; 
                 border:2px solid grey; z-index:9999; font-size:14px;
                 background-color:white; opacity: .85;">
     &nbsp; Fees ranges <br>
     &nbsp; <1k <i style="background: blue; width: 18px; height: 18px; border-radius: 50%; display: inline-block;"></i><br>
     &nbsp; 1k-10k <i style="background: green; width: 18px; height: 18px; border-radius: 50%; display: inline-block;"></i><br>
     &nbsp; 10k-100k <i style="background: orange; width: 18px; height: 18px; border-radius: 50%; display: inline-block;"></i><br>
     &nbsp; 100k-1M <i style="background: red; width: 18px; height: 18px; border-radius: 50%; display: inline-block;"></i><br>
     &nbsp; >1M <i style="background: purple; width: 18px; height: 18px; border-radius: 50%; display: inline-block;"></i><br>
      </div>
     '''

m.get_root().html.add_child(folium.Element(legend_html))

# Display the map
m
# Out:
# Requirement already satisfied: folium in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (0.15.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (2023.7.22)
# Requirement already satisfied: folium in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (0.15.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/erikazetu/anaconda3/lib/python3.11/site-packages (from requests->folium) (2023.7.22)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bee740f039e59482ad08aa874f77c2e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;div style=&quot;position: fixed;
#                  bottom: 50px; left: 50px; width: 150px; height: 180px;
#                  border:2px solid grey; z-index:9999; font-size:14px;
#                  background-color:white; opacity: .85;&quot;&gt;
#      &amp;nbsp; Fees ranges &lt;br&gt;
#      &amp;nbsp; &lt;1k &lt;i style=&quot;background: blue; width: 18px; height: 18px; border-radius: 50%; display: inline-block;&quot;&gt;&lt;/i&gt;&lt;br&gt;
#      &amp;nbsp; 1k-10k &lt;i style=&quot;background: green; width: 18px; height: 18px; border-radius: 50%; display: inline-block;&quot;&gt;&lt;/i&gt;&lt;br&gt;
#      &amp;nbsp; 10k-100k &lt;i style=&quot;background: orange; width: 18px; height: 18px; border-radius: 50%; display: inline-block;&quot;&gt;&lt;/i&gt;&lt;br&gt;
#      &amp;nbsp; 100k-1M &lt;i style=&quot;background: red; width: 18px; height: 18px; border-radius: 50%; display: inline-block;&quot;&gt;&lt;/i&gt;&lt;br&gt;
#      &amp;nbsp; &gt;1M &lt;i style=&quot;background: purple; width: 18px; height: 18px; border-radius: 50%; display: inline-block;&quot;&gt;&lt;/i&gt;&lt;br&gt;
#       &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bee740f039e59482ad08aa874f77c2e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bee740f039e59482ad08aa874f77c2e6 = L.map(
#                 &quot;map_bee740f039e59482ad08aa874f77c2e6&quot;,
#                 {
#                     center: [51.03856393249152, 3.403841842508143],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22d0d1f5fa85c09b982c9cad9f355bfd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_22d0d1f5fa85c09b982c9cad9f355bfd.addTo(map_bee740f039e59482ad08aa874f77c2e6);
#
#             var marker_cluster_c5b904d6b9adeea2870be7ae99ce82f7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_47e9fa2b00b3837d0c7a31bfba617b92 = L.marker(
#                 [53.8007554, -1.5490774],
#                 {}
#             ).addTo(marker_cluster_c5b904d6b9adeea2870be7ae99ce82f7);
#
#
#             var icon_4bd7e231d80a4a1bef0bf8b510173ceb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47e9fa2b00b3837d0c7a31bfba617b92.setIcon(icon_4bd7e231d80a4a1bef0bf8b510173ceb);
#
#
#         var popup_5d78b49c29def1061717295f040d0ac8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc7de6f6498b17feb4b482cc15323cf4 = $(`&lt;div id=&quot;html_fc7de6f6498b17feb4b482cc15323cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Leeds,United Kingdom&lt;/div&gt;`)[0];
#                 popup_5d78b49c29def1061717295f040d0ac8.setContent(html_fc7de6f6498b17feb4b482cc15323cf4);
#
#
#
#         marker_47e9fa2b00b3837d0c7a31bfba617b92.bindPopup(popup_5d78b49c29def1061717295f040d0ac8)
#         ;
#
#
#
#
#             marker_47e9fa2b00b3837d0c7a31bfba617b92.bindTooltip(
#                 `&lt;div&gt;
#                      Accounting and Finance - MSc
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_159f74bf37bbd68985d0fbf65aa195af = L.marker(
#                 [53.8007554, -1.5490774],
#                 {}
#             ).addTo(marker_cluster_c5b904d6b9adeea2870be7ae99ce82f7);
#
#
#             var icon_9dcf7e1c89901a893ccaad8cef5fdbc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_159f74bf37bbd68985d0fbf65aa195af.setIcon(icon_9dcf7e1c89901a893ccaad8cef5fdbc3);
#
#
#         var popup_8c941c3ee21f71bd9d196e58602f6433 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# The second option is:

# %%
import plotly.express as px
import geopandas as gpd
import pandas as pd

#variables which will be visible for each course on the map
hover_data_columns = ['courseName', 'fees_interval', 'city', 'country']

#dot's color
color_order = ['blue', 'green', 'orange', 'red', 'purple'] 

#define the points: location and color
fig = px.scatter_geo(courses,
                     lat=courses['Lat'], 
                     lon=courses['Lon'], 
                     hover_name="courseName", 
                     color="fees_interval",
                     category_orders={"fees_interval": labels},
                     color_discrete_sequence=color_order,
                     projection="natural earth",
                     custom_data=courses[hover_data_columns])

#add the legend
fig.update_layout(legend_title_text='Fees Interval')

#customize the hover information that is displayed when you hover over a data point on the Plotly scatter plot.
fig.update_traces(hovertemplate="<br>".join(["%{customdata[" + str(i) + "]}" for i in range(len(hover_data_columns))]))

#show the figure
fig.show()
# Out:
# <div>                            <div id="1ba8d871-f183-4c3f-a390-c6ea0f344c2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ba8d871-f183-4c3f-a390-c6ea0f344c2f")) {                    Plotly.newPlot(                        "1ba8d871-f183-4c3f-a390-c6ea0f344c2f",                        [{"customdata":[["Applied Economics (Banking and Financial Markets), online MSc","<1k","Bath","United Kingdom"],["Business Analytics, online MSc","<1k","Bath","United Kingdom"],["Coastal and Marine Management","<1k","Isafjorour","Iceland"],["Economics of Markets and Organisations","<1k","Rotterdam","Netherlands"],["Economics of Sustainability","<1k","Rotterdam","Netherlands"],["Entrepreneurship Management and Innovation, online MSc","<1k","Bath","United Kingdom"],["International Economics (MSc)","<1k","Rotterdam","Netherlands"],["M.Sc. DevOps and Cloud Computing","<1k","Berlin","Germany"],["MSc in Anthropology and Development Studies","<1k","Nijmegen","Netherlands"],["MSc in Artificial Intelligence","<1k","Nijmegen","Netherlands"],["MSc in Behaviour Change","<1k","Nijmegen","Netherlands"],["MSc in Behavioural Science (Research)","<1k","Nijmegen","Netherlands"],["MSc in Biology","<1k","Nijmegen","Netherlands"],["MSc in Biomedical Sciences","<1k","Nijmegen","Netherlands"],["MSc in Business Administration","<1k","Nijmegen","Netherlands"],["MSc in Cognitive Neuroscience (Research)","<1k","Nijmegen","Netherlands"],["MSc in Conflicts, Territories and Identities","<1k","Nijmegen","Netherlands"],["MSc in Cyber Security","<1k","Nijmegen","Netherlands"],["MSc in Economics, Behaviour and Policy","<1k","Nijmegen","Netherlands"],["MSc in Environment and Society Studies","<1k","Nijmegen","Netherlands"],["MSc in International Business","<1k","Nijmegen","Netherlands"],["MSc in International Relations","<1k","Nijmegen","Netherlands"],["MSc in Mathematics","<1k","Nijmegen","Netherlands"],["MSc in Medical Biology","<1k","Nijmegen","Netherlands"],["MSc in Molecular Mechanisms of Disease (Research)","<1k","Nijmegen","Netherlands"],["MSc in Neurophysics","<1k","Nijmegen","Netherlands"],["MSc in Particle and Astrophysics","<1k","Nijmegen","Netherlands"],["MSc in Quantum Matter","<1k","Nijmegen","Netherlands"],["MSc in Software Science","<1k","Nijmegen","Netherlands"],["MSc in Spatial Planning","<1k","Nijmegen","Netherlands"],["Strategy Economics (MSc)","<1k","Rotterdam","Netherlands"],["Urban, Port and Transport Economics (MSc)","<1k","Rotterdam","Netherlands"],["Accounting, Auditing and Control(MSc)","<1k","Rotterdam","Netherlands"],["Advanced Clinical Practice MSc/PGDip","<1k","London","United Kingdom"],["Advanced Medical Imaging - MSc","<1k","Hatfield","United Kingdom"],["Advanced Radiotherapy and Oncology Practice - MSc","<1k","Hatfield","United Kingdom"],["Analytics and Operations Research in Logistics (MSc)","<1k","Rotterdam","Netherlands"],["Applied Clinical Research (M.S.)","<1k","St Cloud","USA"],["Applied Computer Science (MSc)","<1k","Heidelberg","Germany"],["Applied Data Science and Analytics (MSc)","<1k","Heidelberg","Germany"],["Applied Image & Signal Processing","<1k","Salzburg","Austria"],["Artificial Intelligence for Science & Technology (Joint Degree)","<1k","Pavia","Italy"],["Artificial Intelligence, online MSc","<1k","Bath","United Kingdom"],["Behavioural Economics (MSc)","<1k","Rotterdam","Netherlands"],["Business Analytics and Quantitative Marketing (MSc)","<1k","Rotterdam","Netherlands"],["Business Management - Business and Organization Psychology","<1k","Berlin","Germany"],["Business Management - HR and Change Management","<1k","Berlin","Germany"],["Business Management - Sustainable Management","<1k","Berlin","Germany"],["Chemistry and Physics of Materials International MSc","<1k","Salzburg","Austria"],["C ...
